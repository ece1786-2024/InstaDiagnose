# %% [markdown]
# # **Data Processing**
#
# https://huggingface.co/datasets/gretelai/symptom_to_diagnosis

# %% [markdown]
# ## Download the datasets

# %%
import pandas as pd

splits = {'train': 'train.jsonl', 'test': 'test.jsonl'}
df1 = pd.read_json("hf://datasets/gretelai/symptom_to_diagnosis/" + splits["train"], lines=True)

splits = {'train': 'train.jsonl', 'test': 'test.jsonl'}
df2 = pd.read_json("hf://datasets/gretelai/symptom_to_diagnosis/" + splits["test"], lines=True)

# %% [markdown]
# ## Data Exploration

# %%
# check the diseases
df = pd.concat([df1, df2], ignore_index = True)
df["output_text"].unique()
# Out:
# array(['cervical spondylosis', 'impetigo', 'urinary tract infection',
#        'arthritis', 'dengue', 'common cold', 'drug reaction',
#        'fungal infection', 'malaria', 'allergy', 'bronchial asthma',
#        'varicose veins', 'migraine', 'hypertension',
#        'gastroesophageal reflux disease', 'pneumonia', 'psoriasis',
#        'diabetes', 'jaundice', 'chicken pox', 'typhoid',
#        'peptic ulcer disease'], dtype=object)

# %%
# check the number of diseases in the dataset
len(df["output_text"].unique())
# Out:
# 22

# %%
# a preview of the dataset
df.head()
# Out:
#                output_text                                         input_text
# 0     cervical spondylosis  I've been having a lot of pain in my neck and ...
# 1                 impetigo  I have a rash on my face that is getting worse...
# 2  urinary tract infection  I have been urinating blood. I sometimes feel ...
# 3                arthritis  I have been having trouble with my muscles and...
# 4                   dengue  I have been feeling really sick. My body hurts...

# %% [markdown]
# ## Data Cleaning

# %%
# check for the missing values
print(df.isnull().values.any())
# Out:
# False

# %%
# Split input_text into individual sentences for easier manipulation and extraction of information.
split_sentence = df["input_text"].str.split(r"\. ", expand = True)
split_sentence.columns = [f'sentence_{i+1}' for i in range(split_sentence.shape[1])]

# Add a period to all sentences that are not the last and do not already end with a period
for col in split_sentence.columns[:-1]:  # Exclude the last column
    split_sentence[col] = split_sentence[col].apply(lambda x: x if pd.isnull(x) or x.endswith('.') else x + '.')

# Ensure the last column does not have an extra period if it's already there
last_col = split_sentence.columns[-1]
split_sentence[last_col] = split_sentence[last_col].apply(lambda x: x if pd.isnull(x) else x.rstrip('.') + '.')

# %%
df_split = pd.concat([df, split_sentence], axis=1)
df_split
# Out:
#                   output_text  \
# 0        cervical spondylosis
# 1                    impetigo
# 2     urinary tract infection
# 3                   arthritis
# 4                      dengue
# ...                       ...
# 1060                   dengue
# 1061                psoriasis
# 1062         bronchial asthma
# 1063         bronchial asthma
# 1064                   dengue
#
#                                              input_text  \
# 0     I've been having a lot of pain in my neck and ...
# 1     I have a rash on my face that is getting worse...
# 2     I have been urinating blood. I sometimes feel ...
# 3     I have been having trouble with my muscles and...
# 4     I have been feeling really sick. My body hurts...
# ...                                                 ...
# 1060  I have been experiencing muscle pain that make...
# 1061  I have red, irritated skin on my arms, face, a...
# 1062  I've been having a hard time breathing, and I'...
# 1063  I've been coughing a lot for a few days now. I...
# 1064  I have a severe headache that feels like press...
#
#                                              sentence_1  \
# 0     I've been having a lot of pain in my neck and ...
# 1       I have a rash on my face that is getting worse.
# 2                          I have been urinating blood.
# 3     I have been having trouble with my muscles and...
# 4                      I have been feeling really sick.
# ...                                                 ...
# 1060  I have been experiencing muscle pain that make...
# 1061  I have red, irritated skin on my arms, face, a...
# 1062  I've been having a hard time breathing, and I'...
# 1063       I've been coughing a lot for a few days now.
# 1064  I have a severe headache that feels like press...
#
#                                              sentence_2  \
# 0     I've also been having trouble with my balance ...
# 1     It is red, inflamed, and has blisters that are...
# 2     I sometimes feel sick to my stomach when I uri...
# 3     My neck is really tight and my muscles feel weak.
# 4           My body hurts a lot and I have no appetite.
# ...                                                 ...
# 1060          I have lost my apetite and feel vomiting.
# 1061                It's often itchy and uncomfortable.
# 1062            I'm also feeling really tired and weak.
# 1063  It's been hard for me to catch my breath, and ...
# 1064  I also have a mild fever and small red spots o...
#
#                                              sentence_3  \
# 0      I've been coughing a lot and my limbs feel weak.
# 1                                 It is really painful.
# 2                     I often feel like I have a fever.
# 3     I have swollen joints and it is hard to move a...
# 4     I have also developed rashes on my arms and face.
# ...                                                 ...
# 1060                       My legs and back pain a lot.
# 1061  My nails are also inflamed and have small dent...
# 1062                                               None
# 1063  I've also been producing a lot of mucus when I...
# 1064                                               None
#
#                                       sentence_4 sentence_5 sentence_6  \
# 0                                           None       None       None
# 1                                           None       None       None
# 2                                           None       None       None
# 3       It is also really uncomfortable to walk.       None       None
# 4                The back of my eyes hurt a lot.       None       None
# ...                                          ...        ...        ...
# 1060    I have been feeling very weak and tired.          .       None
# 1061  I've never seen anything like this before.       None       None
# 1062                                        None       None       None
# 1063                                        None       None       None
# 1064                                        None       None       None
#
#      sentence_7
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# 1060       None
# 1061       None
# 1062       None
# 1063       None
# 1064       None
#
# [1065 rows x 9 columns]

# %% [markdown]
# ## Create the test set for the evaluation

# %%
df_more_than_2_sentence = df_split[df_split.iloc[:, 2:].notnull().sum(axis=1)>2]

# %%
df_more_than_2_sentence["output_text"].unique()
# Out:
# array(['cervical spondylosis', 'impetigo', 'urinary tract infection',
#        'arthritis', 'dengue', 'common cold', 'malaria', 'allergy',
#        'bronchial asthma', 'migraine', 'drug reaction',
#        'gastroesophageal reflux disease', 'pneumonia', 'psoriasis',
#        'diabetes', 'jaundice', 'chicken pox', 'typhoid',
#        'peptic ulcer disease', 'varicose veins', 'fungal infection',
#        'hypertension'], dtype=object)

# %%
len(df_more_than_2_sentence["output_text"].unique())
# Out:
# 22

# %%
df_more_than_2_sentence.groupby("output_text")["output_text"].count()
# Out:
# output_text
# allergy                            34
# arthritis                          30
# bronchial asthma                   37
# cervical spondylosis               11
# chicken pox                        25
# common cold                        47
# dengue                             32
# diabetes                           25
# drug reaction                      22
# fungal infection                   15
# gastroesophageal reflux disease    22
# hypertension                       11
# impetigo                           24
# jaundice                           40
# malaria                            46
# migraine                            9
# peptic ulcer disease               32
# pneumonia                          46
# psoriasis                          29
# typhoid                            32
# urinary tract infection            29
# varicose veins                     20
# Name: output_text, dtype: int64

# %%
df_sampled = df_more_than_2_sentence.groupby("output_text", group_keys=False)\
                                    .sample(n=3, replace=True, random_state=1)

df_sampled
# Out:
#                  output_text  \
# 294                  allergy
# 173                  allergy
# 199                  allergy
# 455                arthritis
# 125                arthritis
# ..                       ...
# 941  urinary tract infection
# 444  urinary tract infection
# 231           varicose veins
# 489           varicose veins
# 541           varicose veins
#
#                                             input_text  \
# 294  My skin is itchy and red. Sometimes, it can pe...
# 173  I have a sore throat and I am sneezing all the...
# 199  I feel sick to my stomach, lightheaded, and di...
# 455  I've been feeling really weak in my muscles an...
# 125  I've been having a lot of pain in my joints, e...
# ..                                                 ...
# 941  I've been having a hard time peeing. It hurts ...
# 444  I've been having to pee a lot, and it hurts wh...
# 231  I have been having cramps in my calves when I ...
# 489  I have some red and inflamed skin on my legs. ...
# 541  I have some veins in my legs that are bulging ...
#
#                                             sentence_1  \
# 294                          My skin is itchy and red.
# 173  I have a sore throat and I am sneezing all the...
# 199  I feel sick to my stomach, lightheaded, and di...
# 455  I've been feeling really weak in my muscles an...
# 125  I've been having a lot of pain in my joints, e...
# ..                                                 ...
# 941               I've been having a hard time peeing.
# 444  I've been having to pee a lot, and it hurts wh...
# 231  I have been having cramps in my calves when I ...
# 489      I have some red and inflamed skin on my legs.
# 541  I have some veins in my legs that are bulging ...
#
#                                             sentence_2  \
# 294                            Sometimes, it can peel.
# 173  Sometimes my face swells up, especially my lip...
# 199     My throat is swollen and I can't breathe well.
# 455  My joints have been swelling up and it's hard ...
# 125  It's hard to move around and I'm always feelin...
# ..                                                 ...
# 941               It hurts when I go, and it's bloody.
# 444  Sometimes I see blood in my pee, and it smells...
# 231     I have also noticed bruise marks on my calves.
# 489  I think I can see some of the swollen blood ve...
# 541                            I'm concerned about it.
#
#                                             sentence_3  \
# 294  My lips and cheeks swell, and it is really ann...
# 173                I can't stop sneezing once I start.
# 199  I sometimes feel pain in my chest and nausea a...
# 455               Walking has been really painful too.
# 125  I've also been having trouble sleeping because...
# ..                                                 ...
# 941     My head hurts, and my urine smells really bad.
# 444              I'm worried that I have an infection.
# 231                            I feel tired very soon.
# 489                       I'm really worried about it.
# 541  I'm also overweight and I think that might be ...
#
#                                             sentence_4 sentence_5 sentence_6  \
# 294  I sometimes get headaches and watery eyes beca...       None       None
# 173                                               None       None       None
# 199                                               None       None       None
# 455                                               None       None       None
# 125                                               None       None       None
# ..                                                 ...        ...        ...
# 941  I can't control when I have to go, and it's re...       None       None
# 444                                 What should I do?.       None       None
# 231                                               None       None       None
# 489                                               None       None       None
# 541                                               None       None       None
#
#     sentence_7
# 294       None
# 173       None
# 199       None
# 455       None
# 125       None
# ..         ...
# 941       None
# 444       None
# 231       None
# 489       None
# 541       None
#
# [66 rows x 9 columns]

# %%
# add "no more information" after the last sentence for each row
for index, row in df_sampled.iterrows():
    has_null = False
    for col in df_sampled.columns[3:]:
        if pd.isnull(row[col]):
            df_sampled.at[index, col] = "no more information"
            has_null = True
            break
            
    if not has_null:
        # If no null columns found, add a new column for this row
        next_col_num = len([col for col in df_sampled.columns if col.startswith('sentence_')]) + 1
        new_col = f'sentence_{next_col_num}'
        if new_col not in df_sampled.columns:
            df_sampled[new_col] = None
        df_sampled.at[index, new_col] = "no more information"

df_sampled
# Out:
#                  output_text  \
# 294                  allergy
# 173                  allergy
# 199                  allergy
# 455                arthritis
# 125                arthritis
# ..                       ...
# 941  urinary tract infection
# 444  urinary tract infection
# 231           varicose veins
# 489           varicose veins
# 541           varicose veins
#
#                                             input_text  \
# 294  My skin is itchy and red. Sometimes, it can pe...
# 173  I have a sore throat and I am sneezing all the...
# 199  I feel sick to my stomach, lightheaded, and di...
# 455  I've been feeling really weak in my muscles an...
# 125  I've been having a lot of pain in my joints, e...
# ..                                                 ...
# 941  I've been having a hard time peeing. It hurts ...
# 444  I've been having to pee a lot, and it hurts wh...
# 231  I have been having cramps in my calves when I ...
# 489  I have some red and inflamed skin on my legs. ...
# 541  I have some veins in my legs that are bulging ...
#
#                                             sentence_1  \
# 294                          My skin is itchy and red.
# 173  I have a sore throat and I am sneezing all the...
# 199  I feel sick to my stomach, lightheaded, and di...
# 455  I've been feeling really weak in my muscles an...
# 125  I've been having a lot of pain in my joints, e...
# ..                                                 ...
# 941               I've been having a hard time peeing.
# 444  I've been having to pee a lot, and it hurts wh...
# 231  I have been having cramps in my calves when I ...
# 489      I have some red and inflamed skin on my legs.
# 541  I have some veins in my legs that are bulging ...
#
#                                             sentence_2  \
# 294                            Sometimes, it can peel.
# 173  Sometimes my face swells up, especially my lip...
# 199     My throat is swollen and I can't breathe well.
# 455  My joints have been swelling up and it's hard ...
# 125  It's hard to move around and I'm always feelin...
# ..                                                 ...
# 941               It hurts when I go, and it's bloody.
# 444  Sometimes I see blood in my pee, and it smells...
# 231     I have also noticed bruise marks on my calves.
# 489  I think I can see some of the swollen blood ve...
# 541                            I'm concerned about it.
#
#                                             sentence_3  \
# 294  My lips and cheeks swell, and it is really ann...
# 173                I can't stop sneezing once I start.
# 199  I sometimes feel pain in my chest and nausea a...
# 455               Walking has been really painful too.
# 125  I've also been having trouble sleeping because...
# ..                                                 ...
# 941     My head hurts, and my urine smells really bad.
# 444              I'm worried that I have an infection.
# 231                            I feel tired very soon.
# 489                       I'm really worried about it.
# 541  I'm also overweight and I think that might be ...
#
#                                             sentence_4           sentence_5  \
# 294  I sometimes get headaches and watery eyes beca...  no more information
# 173                                no more information                 None
# 199                                no more information                 None
# 455                                no more information                 None
# 125                                no more information                 None
# ..                                                 ...                  ...
# 941  I can't control when I have to go, and it's re...  no more information
# 444                                 What should I do?.  no more information
# 231                                no more information                 None
# 489                                no more information                 None
# 541                                no more information                 None
#
#     sentence_6 sentence_7 sentence_8
# 294       None       None       None
# 173       None       None       None
# 199       None       None       None
# 455       None       None       None
# 125       None       None       None
# ..         ...        ...        ...
# 941       None       None       None
# 444       None       None       None
# 231       None       None       None
# 489       None       None       None
# 541       None       None       None
#
# [66 rows x 10 columns]

# %%
df_sampled.to_csv("sampled_df.csv", index = False)
